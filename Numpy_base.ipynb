# %%
import numpy as np

# %%
scalaire_1 = np.array(5)
scalaire_2 = np.array(6)
scalaire_1 + scalaire_2
# Out:
# np.int64(11)

# %%
scalaire_1 = np.array(5)
scalaire_2 = np.array(6)
resultat = scalaire_1 + scalaire_2
resultat
# Out:
# np.int64(11)

# %%
print(np.array(5) + np.array(6))
# Out:
# 11

# %%
vecteur_1 = np.array([1, 2, 3])
vecteur_2 = np.array([3, 2, 1])
vecteur_3 = np.array([0, 1, -1])
resultat = vecteur_1 + vecteur_2 + vecteur_3
print(resultat)
print(resultat.shape)
# Out:
# [4 5 3]
# (3,)

# %%
vecteur_1, vecteur_2, vecteur_3 = np.array([1, 2, 3]), np.array([3, 2, 1]), np.array([0, 1, -1])
print(vecteur_1+vecteur_2+vecteur_3)
print((vecteur_1+vecteur_2+vecteur_3).shape)
# Out:
# [4 5 3]
# (3,)

# %%
resultat = np.array([1, 2, 3]) + np.array([3, 2, 1]) + np.array([0, 1, -1])
print(resultat)
print(resultat.shape)
# Out:
# [4 5 3]
# (3,)

# %%
scalaire = np.array(0)
vecteur = np.array([125, 2185, 321, 665, 17, -8])
produit = scalaire * vecteur
print(produit)
# Out:
# [0 0 0 0 0 0]

# %%
m = np.array([[1, 2, 3], [4, 5, 6]])
m
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
m1 = np.array([[1, 2], [3, 4], [5, 6], [7, 8]])
m2 = np.array([[8, 7], [6, 5], [4, 3], [2, 1]])
m1 + m2
# Out:
# array([[9, 9],
#        [9, 9],
#        [9, 9],
#        [9, 9]])

# %%
import numpy as np

v1 = np.array([4, 7])
v2 = np.array([3, 6])

scalaire_a1 = np.array(2)
scalaire_a2 = np.array(3)
scalaire_a3 = np.array(1.5)

v1 = v1 * scalaire_a1
v2 = v2 * scalaire_a2

v3 = v1 + v2
resultat = v3 * scalaire_a3

print(resultat)
# Out:
# [25.5 48. ]
